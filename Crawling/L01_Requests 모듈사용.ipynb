# %%
import requests

# %% [markdown]
# get 요청하기

# %%
url = 'https://news.v.daum.net/v/20190728165812603'

resp = requests.get(url)
resp.text # 페이지 소스
# Out:
# '<!doctype html>\n<html lang="ko"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <style>\n             @import url(\'//t1.daumcdn.net/harmony_static/cloud/page/2603111efaebe3b9879c7b3c1417b82fff251095.css\');\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/2020/08/31/components.3a29e3019a672c3d2abf.css\')\n        </style> \n  <meta name="robots" content="noindex"> \n  <meta property="mccp:docId" content="NHT9NtZWBe"> \n  <meta property="og:site_name" content="다음 뉴스" data-cloud="pc_html_head_meta"> \n  <meta property="og:title" content="일론머스크 &quot;테슬라에서 넷플릭스·유튜브 즐길 날 온다&quot;" data-cloud="pc_html_head_meta"> \n  <meta property="og:regDate" content="20190728165812" data-cloud="pc_html_head_meta"> \n  <meta property="og:description" content="[아시아경제 이민우 기자] 일론 머스크 테슬라 최고경영자(CEO)가 자사 전기 자동차 모델에 넷플릭스와 유튜브 등 온라인동영상서비스(OTT)를 탑재할 것이라고 예고했다. 단순히 자율 주행 전기차가 단순히 주행을 위한 정보를 알려주는 것을 넘어 각종 영상 콘텐츠를 즐기는 공간으
# ...

# %% [markdown]
# post 요청하기

# %%
url = 'https://www.kangcom.com/member/member_check.asp'
data = {
    'id': 'macmath22',
    'pwd': 'Test1357!'
}

resp = requests.post(url, data=data) # 로그인될 경우, 정상 페이지 동작
resp.text
# Out:
# '\n<!doctype html>\n<html lang="ko">\n<head>\n\t<meta charset="euc-kr" />\n\t<meta http-equiv="x-dns-prefetch-control" content="on" />\n\t<link rel="dns-prefetch" href="//image.kangcom.com" />\n\t<link rel="dns-prefetch" href="//image3.kangcom.com" />\t\n\t<link rel="dns-prefetch" href="//fonts.googleapis.com" />\n\t<meta name="google-site-verification" content="htIs7dHpmwTsnu80zA7uovWB8MOW5C9KembN12Hg9X8" />\n\t<meta name="title" content="강컴닷컴" />\n\t<meta name="description" content="국내도서, 영어원서, 외국도서 직수입 판매, 구매대행 전문 인터넷서점." />\n\t<meta property="og:image" content="http://image.kangcom.com/site/images/kangcom_200x200.png" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge,requiresActiveX=true" />\n\t<title>지식발전소 강컴닷컴</title>\n\t<link rel="stylesheet" type="text/css" href="/css/normalize.css" />\n\t<link rel="stylesheet" type="text/css" href="/css/global.css" />\n\t<link href="https://fonts.googleapis.com/css?family=Roboto:400,700" rel="stylesheet" type="text/css">\n\t<!--[if I
# ...

# %%
data = {
    'id': 'macmath22',
    'pwd': 'notpasswd'
}

resp = requests.post(url, data=data) # 로그인안 될 경우, 해당 페이지 동작
resp.text
# Out:
# '\n\t\t<script language="javascript">\n\t\t{\n\t\t\talert("ID가 잘못되었거나 비밀번호가 잘못되었습니다!\\n\\n다시 한번확인해 주세요!");\n\t\t\thistory.back ();\n\t\t}\n\t\t</script>\n'

# %% [markdown]
# HTTP headeer 데이터 이용하기

# %%
url = 'https://news.v.daum.net/v/20190728165812603' # url로 크롤러가 안될 경우, headers를 명시 후 전달하여 페이지소스를 가져올 수 있음
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36'
}
resp = requests.get(url, headers=headers)
resp.text # 페이지 소스
# Out:
# '<!doctype html>\n<html lang="ko"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <style>\n             @import url(\'//t1.daumcdn.net/harmony_static/cloud/page/2603111efaebe3b9879c7b3c1417b82fff251095.css\');\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/2020/08/31/components.3a29e3019a672c3d2abf.css\')\n        </style> \n  <meta name="robots" content="noindex"> \n  <meta property="mccp:docId" content="NHT9NtZWBe"> \n  <meta property="og:site_name" content="다음 뉴스" data-cloud="pc_html_head_meta"> \n  <meta property="og:title" content="일론머스크 &quot;테슬라에서 넷플릭스·유튜브 즐길 날 온다&quot;" data-cloud="pc_html_head_meta"> \n  <meta property="og:regDate" content="20190728165812" data-cloud="pc_html_head_meta"> \n  <meta property="og:description" content="[아시아경제 이민우 기자] 일론 머스크 테슬라 최고경영자(CEO)가 자사 전기 자동차 모델에 넷플릭스와 유튜브 등 온라인동영상서비스(OTT)를 탑재할 것이라고 예고했다. 단순히 자율 주행 전기차가 단순히 주행을 위한 정보를 알려주는 것을 넘어 각종 영상 콘텐츠를 즐기는 공간으
# ...

# %% [markdown]
# HTTP response 처리하기

# %%
url = 'https://news.v.daum.net/v/20190728165812603' # url로 크롤러가 안될 경우, headers를 명시 후 전달하여 페이지소스를 가져올 수 있음

resp = requests.get(url)
if resp.status_code == 200:
    print(resp.text)
else:
    print('error')
# Out:
# <!doctype html>
# <html lang="ko">
#  <head data-cloud-area="head">
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <style>
#              @import url('//t1.daumcdn.net/harmony_static/cloud/page/2603111efaebe3b9879c7b3c1417b82fff251095.css');
#             @import url('//t1.daumcdn.net/harmony_static/cloud/2020/08/31/components.3a29e3019a672c3d2abf.css')
#         </style>
#   <meta name="robots" content="noindex">
#   <meta property="mccp:docId" content="NHT9NtZWBe">
#   <meta property="og:site_name" content="다음 뉴스" data-cloud="pc_html_head_meta">
#   <meta property="og:title" content="일론머스크 &quot;테슬라에서 넷플릭스·유튜브 즐길 날 온다&quot;" data-cloud="pc_html_head_meta">
#   <meta property="og:regDate" content="20190728165812" data-cloud="pc_html_head_meta">
# ...
